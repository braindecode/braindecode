# %%
# %load_ext autoreload
# %autoreload 2
import os
os.sys.path.insert(0, '/home/schirrmr/braindecode/code/braindecode/')

# %% [markdown]
# # Using the Experiment Class

# %% [markdown]
# Braindecode provides a convenience `Experiment` class, which removes the necessity to write your own training loop. It expects a training, a validation and a test set and trains as follows:
# 1. Train on training set until a given stop criterion is fulfilled
# 2. Reset to the best epoch, i.e. reset parameters of the model and the optimizer to the state at the best epoch ("best" according to a given criterion)
# 3. Continue training on the combined training + validation set until the loss on the validation set is as low as it was on the best epoch for the training set. (or until the ConvNet was trained twice as many epochs as the best epoch to prevent infinite training)
#
# <div class='alert alert-warning'>
#
# It is not necessary to use the Experiment class to use the other functionality of Braindecode. Feel free to ignore it :)
#
# </div>

# %% [markdown]
# ## Load data

# %%
# %%capture
import mne

physionet_paths = mne.datasets.eegbci.load_data(1, [5,6,9,10,13,14])

parts = [mne.io.read_raw_edf(path, preload=True,stim_channel='auto')
         for path in physionet_paths]

from mne.io import concatenate_raws

raw = concatenate_raws(parts)
eeg_channel_inds = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                   exclude='bads')
events = mne.find_events(raw, shortest_event=0, stim_channel='STI 014')

epoched = mne.Epochs(raw, events, dict(hands=2, feet=3), tmin=1, tmax=4.1,
                     proj=False, picks=eeg_channel_inds,
                     baseline=None, preload=True)

# %% [markdown]
# ## Convert data to Braindecode Format

# %%
import numpy as np
# Convert data from volt to millivolt
# Pytorch expects float32 for input and int64 for labels.
X = (epoched.get_data() * 1e6).astype(np.float32)
y = (epoched.events[:,2] - 2).astype(np.int64) #2,3 -> 0,1

from braindecode.datautil.signal_target import SignalAndTarget
from braindecode.datautil.splitters import split_into_two_sets

train_set = SignalAndTarget(X[:60], y=y[:60])
test_set = SignalAndTarget(X[60:], y=y[60:])

train_set, valid_set = split_into_two_sets(train_set, first_set_fraction=0.8)

# %% [markdown]
# ## Create the model

# %%
from braindecode.models.shallow_fbcsp import ShallowFBCSPNet
from torch import nn
from braindecode.torch_ext.util import set_random_seeds, to_dense_prediction_model

# Set if you want to use GPU
# You can also use torch.cuda.is_available() to determine if cuda is available on your machine.
cuda = False
set_random_seeds(seed=20170629, cuda=cuda)

# This will determine how many crops are processed in parallel
input_time_length = 450
n_classes = 2
in_chans = train_set.X.shape[1]
# final_conv_length determines the size of the receptive field of the ConvNet
model = ShallowFBCSPNet(in_chans=in_chans, n_classes=n_classes, input_time_length=input_time_length,
                        final_conv_length=12).create_network()
to_dense_prediction_model(model)

if cuda:
    model.cuda()

# %%
from torch import optim

optimizer = optim.Adam(model.parameters())

# %%
from braindecode.torch_ext.util import np_to_var
# determine output size
test_input = np_to_var(np.ones((2, 64, input_time_length, 1), dtype=np.float32))
if cuda:
    test_input = test_input.cuda()
out = model(test_input)
n_preds_per_input = out.cpu().data.numpy().shape[2]
print("{:d} predictions per input/trial".format(n_preds_per_input))
# Out:
# 187 predictions per input/trial

# %%
from braindecode.datautil.iterators import CropsFromTrialsIterator
iterator = CropsFromTrialsIterator(batch_size=32,input_time_length=input_time_length,
                                  n_preds_per_input=n_preds_per_input)

# %%
from braindecode.experiments.experiment import Experiment

# %%
from braindecode.experiments.monitors import RuntimeMonitor, LossMonitor, CroppedTrialMisclassMonitor, MisclassMonitor
from braindecode.experiments.stopcriteria import MaxEpochs
import torch.nn.functional as F
import torch as th
from braindecode.torch_ext.modules import Expression


loss_function = lambda preds, targets: F.nll_loss(th.mean(preds, dim=2)[:,:,0], targets)

model_constraint = None
monitors = [LossMonitor(), MisclassMonitor(col_suffix='sample_misclass'),
            CroppedTrialMisclassMonitor(input_time_length), RuntimeMonitor(),]
stop_criterion = MaxEpochs(20)
exp = Experiment(model, train_set, valid_set, test_set, iterator, loss_function, optimizer, model_constraint,
          monitors, stop_criterion, remember_best_column='valid_misclass',
          run_after_early_stop=True, batch_modifier=None, cuda=cuda)

# %%
import logging
import sys
logging.basicConfig(format='%(asctime)s %(levelname)s : %(message)s',
                     level=logging.DEBUG, stream=sys.stdout)
exp.run()
# Out:
# 2017-07-04 18:28:19,885 INFO : Run until first stop...
# 2017-07-04 18:28:20,332 INFO : Epoch 0
# 2017-07-04 18:28:20,334 INFO : train_loss                0.86930
# 2017-07-04 18:28:20,336 INFO : valid_loss                0.74838
# 2017-07-04 18:28:20,337 INFO : test_loss                 0.69756
# 2017-07-04 18:28:20,339 INFO : train_sample_misclass     0.53894
# 2017-07-04 18:28:20,340 INFO : valid_sample_misclass     0.47103
# 2017-07-04 18:28:20,341 INFO : test_sample_misclass      0.44251
# 2017-07-04 18:28:20,343 INFO : train_misclass            0.60417
# 2017-07-04 18:28:20,344 INFO : valid_misclass            0.50000
# 2017-07-04 18:28:20,346 INFO : test_misclass             0.40000
# 2017-07-04 18:28:20,347 INFO : runtime                   0.00000
# 2017-07-04 18:28:20,349 INFO :
# 2017-07-04 18:28:20,351 INFO : New best valid_misclass: 0.500000
# 2017-07-04 18:28:20,352 INFO :
# 2017-07-04 18:28:22,367 INFO : Epoch 1
# 2017-07-04 18:28:22,373 INFO : train_loss                2.33626
# 2017-07-04 18:28:22,374 INFO : valid_loss                2.31771
# 2017-07-04 18:28:22,376 INFO : test_loss                 2.14077
# 2017-07-04 18:28:22,377 INFO : train_sample_misclass     0.48279
# 2017-07-04 18:28:22,379 INFO : valid_sample_misclass     0.50000
# 2017-07-04 18:28:22,381 INFO : test_sample_misclass      0.46667
# 2017-07-04 18:28:22,382 INFO : train_misclass            0.50000
# 2017-07-04 18:28:22,384 INFO : valid_misclass            0.50000
# 2017-07-04 18:28:22,385 INFO : test_misclass             0.46667
# 2017-07-04 18:28:22,387 INFO : runtime                   1.95942
# 2017-07-04 18:28:22,388 INFO :
# 2017-07-04 18:28:22,391 INFO : New best valid_misclass: 0.500000
# 2017-07-04 18:28:22,393 INFO :
# 2017-07-04 18:28:24,019 INFO : Epoch 2
# 2017-07-04 18:28:24,022 INFO : train_loss                0.59815
# 2017-07-04 18:28:24,023 INFO : valid_loss                0.78503
# 2017-07-04 18:28:24,025 INFO : test_loss                 0.70060
# 2017-07-04 18:28:24,026 INFO : train_sample_misclass     0.33918
# 2017-07-04 18:28:24,028 INFO : valid_sample_misclass     0.47995
# 2017-07-04 18:28:24,029 INFO : test_sample_misclass      0.41996
# 2017-07-04 18:28:24,031 INFO : train_misclass            0.22917
# 2017-07-04 18:28:24,032 INFO : valid_misclass            0.41667
# 2017-07-04 18:28:24,034 INFO : test_misclass             0.43333
# 2017-07-04 18:28:24,035 INFO : runtime                   1.74412
# 2017-07-04 18:28:24,037 INFO :
# 2017-07-04 18:28:24,039 INFO : New best valid_misclass: 0.416667
# 2017-07-04 18:28:24,041 INFO :
# 2017-07-04 18:28:25,748 INFO : Epoch 3
# 2017-07-04 18:28:25,751 INFO : train_loss                0.53121
# 2017-07-04 18:28:25,752 INFO : valid_loss                0.87284
# 2017-07-04 18:28:25,754 INFO : test_loss                 0.69774
# 2017-07-04 18:28:25,755 INFO : train_sample_misclass     0.24588
# 2017-07-04 18:28:25,757 INFO : valid_sample_misclass     0.55548
# 2017-07-04 18:28:25,758 INFO : test_sample_misclass      0.42709
# 2017-07-04 18:28:25,760 INFO : train_misclass            0.22917
# 2017-07-04 18:28:25,761 INFO : valid_misclass            0.50000
# 2017-07-04 18:28:25,763 INFO : test_misclass             0.36667
# 2017-07-04 18:28:25,764 INFO : runtime                   1.69212
# 2017-07-04 18:28:25,766 INFO :
# 2017-07-04 18:28:27,354 INFO : Epoch 4
# 2017-07-04 18:28:27,357 INFO : train_loss                0.51574
# 2017-07-04 18:28:27,359 INFO : valid_loss                1.10377
# 2017-07-04 18:28:27,360 INFO : test_loss                 0.80095
# 2017-07-04 18:28:27,362 INFO : train_sample_misclass     0.25869
# 2017-07-04 18:28:27,363 INFO : valid_sample_misclass     0.60094
# 2017-07-04 18:28:27,365 INFO : test_sample_misclass      0.42727
# 2017-07-04 18:28:27,366 INFO : train_misclass            0.27083
# 2017-07-04 18:28:27,368 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:27,369 INFO : test_misclass             0.46667
# 2017-07-04 18:28:27,371 INFO : runtime                   1.60633
# 2017-07-04 18:28:27,372 INFO :
# 2017-07-04 18:28:28,939 INFO : Epoch 5
# 2017-07-04 18:28:28,942 INFO : train_loss                0.52613
# 2017-07-04 18:28:28,944 INFO : valid_loss                1.22322
# 2017-07-04 18:28:28,945 INFO : test_loss                 0.86285
# 2017-07-04 18:28:28,947 INFO : train_sample_misclass     0.27635
# 2017-07-04 18:28:28,948 INFO : valid_sample_misclass     0.58445
# 2017-07-04 18:28:28,950 INFO : test_sample_misclass      0.43841
# 2017-07-04 18:28:28,951 INFO : train_misclass            0.33333
# 2017-07-04 18:28:28,953 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:28,954 INFO : test_misclass             0.46667
# 2017-07-04 18:28:28,956 INFO : runtime                   1.62098
# 2017-07-04 18:28:28,957 INFO :
# 2017-07-04 18:28:30,633 INFO : Epoch 6
# 2017-07-04 18:28:30,636 INFO : train_loss                0.54906
# 2017-07-04 18:28:30,638 INFO : valid_loss                1.23573
# 2017-07-04 18:28:30,640 INFO : test_loss                 0.92210
# 2017-07-04 18:28:30,642 INFO : train_sample_misclass     0.28816
# 2017-07-04 18:28:30,644 INFO : valid_sample_misclass     0.53810
# 2017-07-04 18:28:30,646 INFO : test_sample_misclass      0.45205
# 2017-07-04 18:28:30,648 INFO : train_misclass            0.33333
# 2017-07-04 18:28:30,649 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:30,651 INFO : test_misclass             0.46667
# 2017-07-04 18:28:30,652 INFO : runtime                   1.68048
# 2017-07-04 18:28:30,654 INFO :
# 2017-07-04 18:28:32,441 INFO : Epoch 7
# 2017-07-04 18:28:32,446 INFO : train_loss                0.59627
# 2017-07-04 18:28:32,447 INFO : valid_loss                1.16602
# 2017-07-04 18:28:32,449 INFO : test_loss                 0.95655
# 2017-07-04 18:28:32,450 INFO : train_sample_misclass     0.32253
# 2017-07-04 18:28:32,452 INFO : valid_sample_misclass     0.53053
# 2017-07-04 18:28:32,453 INFO : test_sample_misclass      0.46346
# 2017-07-04 18:28:32,455 INFO : train_misclass            0.37500
# 2017-07-04 18:28:32,456 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:32,458 INFO : test_misclass             0.46667
# 2017-07-04 18:28:32,459 INFO : runtime                   1.74734
# 2017-07-04 18:28:32,461 INFO :
# 2017-07-04 18:28:34,098 INFO : Epoch 8
# 2017-07-04 18:28:34,100 INFO : train_loss                0.40527
# 2017-07-04 18:28:34,102 INFO : valid_loss                0.95821
# 2017-07-04 18:28:34,103 INFO : test_loss                 0.79267
# 2017-07-04 18:28:34,105 INFO : train_sample_misclass     0.19112
# 2017-07-04 18:28:34,106 INFO : valid_sample_misclass     0.52607
# 2017-07-04 18:28:34,108 INFO : test_sample_misclass      0.43351
# 2017-07-04 18:28:34,109 INFO : train_misclass            0.16667
# 2017-07-04 18:28:34,111 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:34,112 INFO : test_misclass             0.40000
# 2017-07-04 18:28:34,114 INFO : runtime                   1.74375
# 2017-07-04 18:28:34,115 INFO :
# 2017-07-04 18:28:35,942 INFO : Epoch 9
# 2017-07-04 18:28:35,944 INFO : train_loss                0.30290
# 2017-07-04 18:28:35,946 INFO : valid_loss                0.89596
# 2017-07-04 18:28:35,948 INFO : test_loss                 0.75205
# 2017-07-04 18:28:35,949 INFO : train_sample_misclass     0.10968
# 2017-07-04 18:28:35,951 INFO : valid_sample_misclass     0.56684
# 2017-07-04 18:28:35,952 INFO : test_sample_misclass      0.43119
# 2017-07-04 18:28:35,954 INFO : train_misclass            0.08333
# 2017-07-04 18:28:35,955 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:35,957 INFO : test_misclass             0.36667
# 2017-07-04 18:28:35,958 INFO : runtime                   1.76466
# 2017-07-04 18:28:35,960 INFO :
# 2017-07-04 18:28:37,805 INFO : Epoch 10
# 2017-07-04 18:28:37,813 INFO : train_loss                0.25623
# 2017-07-04 18:28:37,814 INFO : valid_loss                0.89555
# 2017-07-04 18:28:37,815 INFO : test_loss                 0.75208
# 2017-07-04 18:28:37,816 INFO : train_sample_misclass     0.06088
# 2017-07-04 18:28:37,817 INFO : valid_sample_misclass     0.55637
# 2017-07-04 18:28:37,818 INFO : test_sample_misclass      0.41765
# 2017-07-04 18:28:37,818 INFO : train_misclass            0.02083
# 2017-07-04 18:28:37,819 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:37,820 INFO : test_misclass             0.33333
# 2017-07-04 18:28:37,821 INFO : runtime                   1.72123
# 2017-07-04 18:28:37,822 INFO :
# 2017-07-04 18:28:39,841 INFO : Epoch 11
# 2017-07-04 18:28:39,842 INFO : train_loss                0.24021
# 2017-07-04 18:28:39,843 INFO : valid_loss                0.90581
# 2017-07-04 18:28:39,844 INFO : test_loss                 0.75648
# 2017-07-04 18:28:39,844 INFO : train_sample_misclass     0.06205
# 2017-07-04 18:28:39,845 INFO : valid_sample_misclass     0.54256
# 2017-07-04 18:28:39,846 INFO : test_sample_misclass      0.39804
# 2017-07-04 18:28:39,846 INFO : train_misclass            0.02083
# 2017-07-04 18:28:39,847 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:39,848 INFO : test_misclass             0.33333
# 2017-07-04 18:28:39,848 INFO : runtime                   2.11895
# 2017-07-04 18:28:39,849 INFO :
# 2017-07-04 18:28:41,615 INFO : Epoch 12
# 2017-07-04 18:28:41,618 INFO : train_loss                0.20491
# 2017-07-04 18:28:41,619 INFO : valid_loss                0.90257
# 2017-07-04 18:28:41,621 INFO : test_loss                 0.75600
# 2017-07-04 18:28:41,622 INFO : train_sample_misclass     0.05041
# 2017-07-04 18:28:41,624 INFO : valid_sample_misclass     0.54055
# 2017-07-04 18:28:41,625 INFO : test_sample_misclass      0.39501
# 2017-07-04 18:28:41,627 INFO : train_misclass            0.00000
# 2017-07-04 18:28:41,628 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:41,630 INFO : test_misclass             0.33333
# 2017-07-04 18:28:41,631 INFO : runtime                   1.83222
# 2017-07-04 18:28:41,633 INFO :
# 2017-07-04 18:28:43,219 INFO : Epoch 13
# 2017-07-04 18:28:43,221 INFO : train_loss                0.17244
# 2017-07-04 18:28:43,223 INFO : valid_loss                0.90562
# 2017-07-04 18:28:43,224 INFO : test_loss                 0.76539
# 2017-07-04 18:28:43,226 INFO : train_sample_misclass     0.03793
# 2017-07-04 18:28:43,227 INFO : valid_sample_misclass     0.56194
# 2017-07-04 18:28:43,229 INFO : test_sample_misclass      0.38752
# 2017-07-04 18:28:43,230 INFO : train_misclass            0.00000
# 2017-07-04 18:28:43,232 INFO : valid_misclass            0.66667
# 2017-07-04 18:28:43,233 INFO : test_misclass             0.36667
# 2017-07-04 18:28:43,235 INFO : runtime                   1.66617
# 2017-07-04 18:28:43,236 INFO :
# 2017-07-04 18:28:44,833 INFO : Epoch 14
# 2017-07-04 18:28:44,835 INFO : train_loss                0.15207
# 2017-07-04 18:28:44,837 INFO : valid_loss                0.90600
# 2017-07-04 18:28:44,838 INFO : test_loss                 0.76428
# 2017-07-04 18:28:44,840 INFO : train_sample_misclass     0.02969
# 2017-07-04 18:28:44,841 INFO : valid_sample_misclass     0.54924
# 2017-07-04 18:28:44,843 INFO : test_sample_misclass      0.36551
# 2017-07-04 18:28:44,844 INFO : train_misclass            0.00000
# 2017-07-04 18:28:44,846 INFO : valid_misclass            0.58333
# 2017-07-04 18:28:44,847 INFO : test_misclass             0.36667
# 2017-07-04 18:28:44,848 INFO : runtime                   1.62278
# 2017-07-04 18:28:44,850 INFO :
# 2017-07-04 18:28:46,495 INFO : Epoch 15
# 2017-07-04 18:28:46,497 INFO : train_loss                0.14998
# 2017-07-04 18:28:46,498 INFO : valid_loss                0.96411
# 2017-07-04 18:28:46,500 INFO : test_loss                 0.81256
# 2017-07-04 18:28:46,501 INFO : train_sample_misclass     0.04027
# 2017-07-04 18:28:46,504 INFO : valid_sample_misclass     0.48061
# 2017-07-04 18:28:46,505 INFO : test_sample_misclass      0.35811
# 2017-07-04 18:28:46,507 INFO : train_misclass            0.02083
# 2017-07-04 18:28:46,508 INFO : valid_misclass            0.50000
# 2017-07-04 18:28:46,510 INFO : test_misclass             0.33333
# 2017-07-04 18:28:46,511 INFO : runtime                   1.65147
# 2017-07-04 18:28:46,513 INFO :
# 2017-07-04 18:28:48,151 INFO : Epoch 16
# 2017-07-04 18:28:48,153 INFO : train_loss                0.10915
# 2017-07-04 18:28:48,155 INFO : valid_loss                0.91490
# 2017-07-04 18:28:48,156 INFO : test_loss                 0.80608
# 2017-07-04 18:28:48,158 INFO : train_sample_misclass     0.01588
# 2017-07-04 18:28:48,159 INFO : valid_sample_misclass     0.54234
# 2017-07-04 18:28:48,161 INFO : test_sample_misclass      0.34537
# 2017-07-04 18:28:48,162 INFO : train_misclass            0.00000
# 2017-07-04 18:28:48,164 INFO : valid_misclass            0.33333
# 2017-07-04 18:28:48,165 INFO : test_misclass             0.33333
# 2017-07-04 18:28:48,167 INFO : runtime                   1.65116
# 2017-07-04 18:28:48,168 INFO :
# 2017-07-04 18:28:48,171 INFO : New best valid_misclass: 0.333333
# 2017-07-04 18:28:48,172 INFO :
# 2017-07-04 18:28:49,752 INFO : Epoch 17
# 2017-07-04 18:28:49,755 INFO : train_loss                0.15003
# 2017-07-04 18:28:49,756 INFO : valid_loss                0.91323
# 2017-07-04 18:28:49,758 INFO : test_loss                 0.81002
# 2017-07-04 18:28:49,759 INFO : train_sample_misclass     0.05403
# 2017-07-04 18:28:49,761 INFO : valid_sample_misclass     0.51337
# 2017-07-04 18:28:49,762 INFO : test_sample_misclass      0.34403
# 2017-07-04 18:28:49,764 INFO : train_misclass            0.04167
# 2017-07-04 18:28:49,765 INFO : valid_misclass            0.50000
# 2017-07-04 18:28:49,766 INFO : test_misclass             0.23333
# 2017-07-04 18:28:49,768 INFO : runtime                   1.59846
# 2017-07-04 18:28:49,769 INFO :
# 2017-07-04 18:28:51,675 INFO : Epoch 18
# 2017-07-04 18:28:51,677 INFO : train_loss                0.09315
# 2017-07-04 18:28:51,677 INFO : valid_loss                0.89064
# 2017-07-04 18:28:51,678 INFO : test_loss                 0.77360
# 2017-07-04 18:28:51,679 INFO : train_sample_misclass     0.01025
# 2017-07-04 18:28:51,679 INFO : valid_sample_misclass     0.49666
# 2017-07-04 18:28:51,680 INFO : test_sample_misclass      0.30873
# 2017-07-04 18:28:51,681 INFO : train_misclass            0.00000
# 2017-07-04 18:28:51,681 INFO : valid_misclass            0.33333
# 2017-07-04 18:28:51,682 INFO : test_misclass             0.33333
# 2017-07-04 18:28:51,683 INFO : runtime                   1.78764
# 2017-07-04 18:28:51,683 INFO :
# 2017-07-04 18:28:51,685 INFO : New best valid_misclass: 0.333333
# 2017-07-04 18:28:51,686 INFO :
# 2017-07-04 18:28:53,396 INFO : Epoch 19
# 2017-07-04 18:28:53,398 INFO : train_loss                0.09407
# 2017-07-04 18:28:53,400 INFO : valid_loss                0.96350
# 2017-07-04 18:28:53,401 INFO : test_loss                 0.84831
# 2017-07-04 18:28:53,403 INFO : train_sample_misclass     0.02078
# 2017-07-04 18:28:53,404 INFO : valid_sample_misclass     0.49042
# 2017-07-04 18:28:53,406 INFO : test_sample_misclass      0.33137
# 2017-07-04 18:28:53,407 INFO : train_misclass            0.00000
# 2017-07-04 18:28:53,409 INFO : valid_misclass            0.50000
# 2017-07-04 18:28:53,410 INFO : test_misclass             0.30000
# 2017-07-04 18:28:53,411 INFO : runtime                   1.79344
# 2017-07-04 18:28:53,413 INFO :
# 2017-07-04 18:28:55,363 INFO : Epoch 20
# 2017-07-04 18:28:55,365 INFO : train_loss                0.06822
# 2017-07-04 18:28:55,367 INFO : valid_loss                1.05598
# 2017-07-04 18:28:55,368 INFO : test_loss                 0.88760
# 2017-07-04 18:28:55,370 INFO : train_sample_misclass     0.00847
# 2017-07-04 18:28:55,371 INFO : valid_sample_misclass     0.51448
# 2017-07-04 18:28:55,373 INFO : test_sample_misclass      0.33066
# 2017-07-04 18:28:55,374 INFO : train_misclass            0.00000
# 2017-07-04 18:28:55,376 INFO : valid_misclass            0.50000
# 2017-07-04 18:28:55,377 INFO : test_misclass             0.36667
# 2017-07-04 18:28:55,379 INFO : runtime                   1.93824
# 2017-07-04 18:28:55,381 INFO :
# 2017-07-04 18:28:55,382 INFO : Setup for second stop...
# 2017-07-04 18:28:55,387 INFO : Train loss to reach 0.09315
# 2017-07-04 18:28:55,388 INFO : Run until second stop...
# 2017-07-04 18:28:55,765 INFO : Epoch 19
# 2017-07-04 18:28:55,767 INFO : train_loss                0.25265
# 2017-07-04 18:28:55,769 INFO : valid_loss                0.89064
# 2017-07-04 18:28:55,770 INFO : test_loss                 0.77360
# 2017-07-04 18:28:55,772 INFO : train_sample_misclass     0.10753
# 2017-07-04 18:28:55,773 INFO : valid_sample_misclass     0.49666
# 2017-07-04 18:28:55,775 INFO : test_sample_misclass      0.30873
# 2017-07-04 18:28:55,776 INFO : train_misclass            0.06667
# 2017-07-04 18:28:55,778 INFO : valid_misclass            0.33333
# 2017-07-04 18:28:55,779 INFO : test_misclass             0.33333
# 2017-07-04 18:28:55,781 INFO : runtime                   0.56407
# 2017-07-04 18:28:55,782 INFO :
# 2017-07-04 18:28:58,359 INFO : Epoch 20
# 2017-07-04 18:28:58,362 INFO : train_loss                0.21080
# 2017-07-04 18:28:58,364 INFO : valid_loss                0.68103
# 2017-07-04 18:28:58,366 INFO : test_loss                 0.73508
# 2017-07-04 18:28:58,367 INFO : train_sample_misclass     0.08324
# 2017-07-04 18:28:58,369 INFO : valid_sample_misclass     0.34915
# 2017-07-04 18:28:58,370 INFO : test_sample_misclass      0.31025
# 2017-07-04 18:28:58,372 INFO : train_misclass            0.10000
# 2017-07-04 18:28:58,373 INFO : valid_misclass            0.50000
# 2017-07-04 18:28:58,375 INFO : test_misclass             0.26667
# 2017-07-04 18:28:58,376 INFO : runtime                   2.41772
# 2017-07-04 18:28:58,378 INFO :
# 2017-07-04 18:29:00,545 INFO : Epoch 21
# 2017-07-04 18:29:00,548 INFO : train_loss                0.18816
# 2017-07-04 18:29:00,549 INFO : valid_loss                0.46174
# 2017-07-04 18:29:00,551 INFO : test_loss                 0.66965
# 2017-07-04 18:29:00,552 INFO : train_sample_misclass     0.07406
# 2017-07-04 18:29:00,554 INFO : valid_sample_misclass     0.24643
# 2017-07-04 18:29:00,555 INFO : test_sample_misclass      0.28066
# 2017-07-04 18:29:00,557 INFO : train_misclass            0.05000
# 2017-07-04 18:29:00,558 INFO : valid_misclass            0.16667
# 2017-07-04 18:29:00,560 INFO : test_misclass             0.26667
# 2017-07-04 18:29:00,561 INFO : runtime                   2.24997
# 2017-07-04 18:29:00,563 INFO :
# 2017-07-04 18:29:02,720 INFO : Epoch 22
# 2017-07-04 18:29:02,723 INFO : train_loss                0.13663
# 2017-07-04 18:29:02,724 INFO : valid_loss                0.28806
# 2017-07-04 18:29:02,726 INFO : test_loss                 0.63335
# 2017-07-04 18:29:02,727 INFO : train_sample_misclass     0.02567
# 2017-07-04 18:29:02,729 INFO : valid_sample_misclass     0.06796
# 2017-07-04 18:29:02,730 INFO : test_sample_misclass      0.25677
# 2017-07-04 18:29:02,732 INFO : train_misclass            0.00000
# 2017-07-04 18:29:02,733 INFO : valid_misclass            0.00000
# 2017-07-04 18:29:02,735 INFO : test_misclass             0.23333
# 2017-07-04 18:29:02,736 INFO : runtime                   2.13436
# 2017-07-04 18:29:02,738 INFO :
# 2017-07-04 18:29:05,273 INFO : Epoch 23
# 2017-07-04 18:29:05,276 INFO : train_loss                0.18469
# 2017-07-04 18:29:05,277 INFO : valid_loss                0.33505
# 2017-07-04 18:29:05,279 INFO : test_loss                 0.74569
# 2017-07-04 18:29:05,280 INFO : train_sample_misclass     0.07469
# 2017-07-04 18:29:05,281 INFO : valid_sample_misclass     0.15575
# 2017-07-04 18:29:05,283 INFO : test_sample_misclass      0.29652
# 2017-07-04 18:29:05,284 INFO : train_misclass            0.05000
# 2017-07-04 18:29:05,286 INFO : valid_misclass            0.08333
# 2017-07-04 18:29:05,287 INFO : test_misclass             0.26667
# 2017-07-04 18:29:05,289 INFO : runtime                   2.54263
# 2017-07-04 18:29:05,290 INFO :
# 2017-07-04 18:29:07,817 INFO : Epoch 24
# 2017-07-04 18:29:07,818 INFO : train_loss                0.12348
# 2017-07-04 18:29:07,819 INFO : valid_loss                0.28360
# 2017-07-04 18:29:07,821 INFO : test_loss                 0.78044
# 2017-07-04 18:29:07,822 INFO : train_sample_misclass     0.03632
# 2017-07-04 18:29:07,824 INFO : valid_sample_misclass     0.10495
# 2017-07-04 18:29:07,825 INFO : test_sample_misclass      0.28529
# 2017-07-04 18:29:07,827 INFO : train_misclass            0.03333
# 2017-07-04 18:29:07,828 INFO : valid_misclass            0.08333
# 2017-07-04 18:29:07,830 INFO : test_misclass             0.26667
# 2017-07-04 18:29:07,831 INFO : runtime                   2.43288
# 2017-07-04 18:29:07,833 INFO :
# 2017-07-04 18:29:10,154 INFO : Epoch 25
# 2017-07-04 18:29:10,157 INFO : train_loss                0.14715
# 2017-07-04 18:29:10,158 INFO : valid_loss                0.19253
# 2017-07-04 18:29:10,160 INFO : test_loss                 0.77622
# 2017-07-04 18:29:10,161 INFO : train_sample_misclass     0.04635
# 2017-07-04 18:29:10,163 INFO : valid_sample_misclass     0.05660
# 2017-07-04 18:29:10,164 INFO : test_sample_misclass      0.26863
# 2017-07-04 18:29:10,166 INFO : train_misclass            0.05000
# 2017-07-04 18:29:10,167 INFO : valid_misclass            0.08333
# 2017-07-04 18:29:10,169 INFO : test_misclass             0.23333
# 2017-07-04 18:29:10,170 INFO : runtime                   2.50245
# 2017-07-04 18:29:10,172 INFO :
# 2017-07-04 18:29:12,281 INFO : Epoch 26
# 2017-07-04 18:29:12,284 INFO : train_loss                0.33871
# 2017-07-04 18:29:12,285 INFO : valid_loss                0.33738
# 2017-07-04 18:29:12,287 INFO : test_loss                 0.75611
# 2017-07-04 18:29:12,288 INFO : train_sample_misclass     0.16430
# 2017-07-04 18:29:12,290 INFO : valid_sample_misclass     0.16689
# 2017-07-04 18:29:12,291 INFO : test_sample_misclass      0.27763
# 2017-07-04 18:29:12,292 INFO : train_misclass            0.11667
# 2017-07-04 18:29:12,294 INFO : valid_misclass            0.16667
# 2017-07-04 18:29:12,295 INFO : test_misclass             0.26667
# 2017-07-04 18:29:12,297 INFO : runtime                   2.04628
# 2017-07-04 18:29:12,298 INFO :
# 2017-07-04 18:29:14,345 INFO : Epoch 27
# 2017-07-04 18:29:14,348 INFO : train_loss                0.12510
# 2017-07-04 18:29:14,349 INFO : valid_loss                0.14954
# 2017-07-04 18:29:14,351 INFO : test_loss                 0.60954
# 2017-07-04 18:29:14,352 INFO : train_sample_misclass     0.03111
# 2017-07-04 18:29:14,354 INFO : valid_sample_misclass     0.02718
# 2017-07-04 18:29:14,355 INFO : test_sample_misclass      0.23351
# 2017-07-04 18:29:14,357 INFO : train_misclass            0.01667
# 2017-07-04 18:29:14,358 INFO : valid_misclass            0.00000
# 2017-07-04 18:29:14,360 INFO : test_misclass             0.16667
# 2017-07-04 18:29:14,361 INFO : runtime                   2.12660
# 2017-07-04 18:29:14,363 INFO :
# 2017-07-04 18:29:16,258 INFO : Epoch 28
# 2017-07-04 18:29:16,260 INFO : train_loss                0.09142
# 2017-07-04 18:29:16,261 INFO : valid_loss                0.15033
# 2017-07-04 18:29:16,263 INFO : test_loss                 0.64889
# 2017-07-04 18:29:16,264 INFO : train_sample_misclass     0.01239
# 2017-07-04 18:29:16,266 INFO : valid_sample_misclass     0.03387
# 2017-07-04 18:29:16,267 INFO : test_sample_misclass      0.25856
# 2017-07-04 18:29:16,269 INFO : train_misclass            0.00000
# 2017-07-04 18:29:16,270 INFO : valid_misclass            0.00000
# 2017-07-04 18:29:16,272 INFO : test_misclass             0.26667
# 2017-07-04 18:29:16,273 INFO : runtime                   1.92528
# 2017-07-04 18:29:16,275 INFO :
# 2017-07-04 18:29:18,353 INFO : Epoch 29
# 2017-07-04 18:29:18,356 INFO : train_loss                0.12668
# 2017-07-04 18:29:18,357 INFO : valid_loss                0.21722
# 2017-07-04 18:29:18,359 INFO : test_loss                 0.74796
# 2017-07-04 18:29:18,360 INFO : train_sample_misclass     0.04274
# 2017-07-04 18:29:18,362 INFO : valid_sample_misclass     0.08623
# 2017-07-04 18:29:18,363 INFO : test_sample_misclass      0.26399
# 2017-07-04 18:29:18,365 INFO : train_misclass            0.03333
# 2017-07-04 18:29:18,366 INFO : valid_misclass            0.08333
# 2017-07-04 18:29:18,368 INFO : test_misclass             0.23333
# 2017-07-04 18:29:18,369 INFO : runtime                   2.10426
# 2017-07-04 18:29:18,371 INFO :
# 2017-07-04 18:29:20,350 INFO : Epoch 30
# 2017-07-04 18:29:20,353 INFO : train_loss                0.07407
# 2017-07-04 18:29:20,354 INFO : valid_loss                0.15270
# 2017-07-04 18:29:20,356 INFO : test_loss                 0.67133
# 2017-07-04 18:29:20,357 INFO : train_sample_misclass     0.01497
# 2017-07-04 18:29:20,359 INFO : valid_sample_misclass     0.06061
# 2017-07-04 18:29:20,360 INFO : test_sample_misclass      0.23975
# 2017-07-04 18:29:20,362 INFO : train_misclass            0.01667
# 2017-07-04 18:29:20,363 INFO : valid_misclass            0.08333
# 2017-07-04 18:29:20,365 INFO : test_misclass             0.20000
# 2017-07-04 18:29:20,366 INFO : runtime                   1.98583
# 2017-07-04 18:29:20,368 INFO :
# 2017-07-04 18:29:22,248 INFO : Epoch 31
# 2017-07-04 18:29:22,250 INFO : train_loss                0.05036
# 2017-07-04 18:29:22,252 INFO : valid_loss                0.09103
# 2017-07-04 18:29:22,253 INFO : test_loss                 0.66769
# 2017-07-04 18:29:22,255 INFO : train_sample_misclass     0.00744
# 2017-07-04 18:29:22,256 INFO : valid_sample_misclass     0.02317
# 2017-07-04 18:29:22,258 INFO : test_sample_misclass      0.20677
# 2017-07-04 18:29:22,259 INFO : train_misclass            0.00000
# 2017-07-04 18:29:22,261 INFO : valid_misclass            0.00000
# 2017-07-04 18:29:22,262 INFO : test_misclass             0.20000
# 2017-07-04 18:29:22,264 INFO : runtime                   1.85101
# 2017-07-04 18:29:22,265 INFO :

# %% [markdown]
# In this case, we arrive at 80.0% accuracy, the training stops after the validation loss decreases below the training loss at the best epoch of 0.03722.

# %% [markdown]
# ## Dataset References

# %% [markdown]
#  This dataset was created and contributed to PhysioNet by the developers of the [BCI2000](http://www.schalklab.org/research/bci2000) instrumentation system, which they used in making these recordings. The system is described in:
#
#      Schalk, G., McFarland, D.J., Hinterberger, T., Birbaumer, N., Wolpaw, J.R. (2004) BCI2000: A General-Purpose Brain-Computer Interface (BCI) System. IEEE TBME 51(6):1034-1043.
#
# [PhysioBank](https://physionet.org/physiobank/) is a large and growing archive of well-characterized digital recordings of physiologic signals and related data for use by the biomedical research community and further described in:
#
#     Goldberger AL, Amaral LAN, Glass L, Hausdorff JM, Ivanov PCh, Mark RG, Mietus JE, Moody GB, Peng C-K, Stanley HE. (2000) PhysioBank, PhysioToolkit, and PhysioNet: Components of a New Research Resource for Complex Physiologic Signals. Circulation 101(23):e215-e220.
