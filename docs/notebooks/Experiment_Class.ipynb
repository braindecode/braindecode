# %%
# %load_ext autoreload
# %autoreload 2
import os
os.sys.path.insert(0, '/home/schirrmr/braindecode/code/braindecode/')

# %% [markdown]
# # Using the Experiment Class

# %% [markdown]
# Braindecode provides a convenience `Experiment` class, which removes the necessity to write your own training loop. It expects a training, a validation and a test set and trains as follows:
# 1. Train on training set until a given stop criterion is fulfilled
# 2. Reset to the best epoch, i.e. reset parameters of the model and the optimizer to the state at the best epoch ("best" according to a given criterion)
# 3. Continue training on the combined training + validation set until the loss on the validation set is as low as it was on the best epoch for the training set. (or until the ConvNet was trained twice as many epochs as the best epoch to prevent infinite training)
#
# <div class='alert alert-warning'>
#
# It is not necessary to use the Experiment class to use the other functionality of Braindecode. Feel free to ignore it :)
#
# </div>

# %% [markdown]
# ## Load data

# %%
# %%capture
import mne

physionet_paths = mne.datasets.eegbci.load_data(1, [5,6,9,10,13,14])

parts = [mne.io.read_raw_edf(path, preload=True,stim_channel='auto')
         for path in physionet_paths]

from mne.io import concatenate_raws

raw = concatenate_raws(parts)
eeg_channel_inds = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                   exclude='bads')
events = mne.find_events(raw, shortest_event=0, stim_channel='STI 014')

epoched = mne.Epochs(raw, events, dict(hands=2, feet=3), tmin=1, tmax=4.1,
                     proj=False, picks=eeg_channel_inds,
                     baseline=None, preload=True)

# %% [markdown]
# ## Convert data to Braindecode Format

# %%
import numpy as np
# Convert data from volt to millivolt
# Pytorch expects float32 for input and int64 for labels.
X = (epoched.get_data() * 1e6).astype(np.float32)
y = (epoched.events[:,2] - 2).astype(np.int64) #2,3 -> 0,1

from braindecode.datautil.signal_target import SignalAndTarget
from braindecode.datautil.splitters import split_into_two_sets

train_set = SignalAndTarget(X[:60], y=y[:60])
test_set = SignalAndTarget(X[60:], y=y[60:])

train_set, valid_set = split_into_two_sets(train_set, first_set_fraction=0.8)

# %% [markdown]
# ## Create the model

# %%
from braindecode.models.shallow_fbcsp import ShallowFBCSPNet
from torch import nn
from braindecode.torch_ext.util import set_random_seeds, to_dense_prediction_model

# Set if you want to use GPU
# You can also use torch.cuda.is_available() to determine if cuda is available on your machine.
cuda = False
set_random_seeds(seed=20170629, cuda=cuda)

# This will determine how many crops are processed in parallel
input_time_length = 450
# final_conv_length determines the size of the receptive field of the ConvNet
model = ShallowFBCSPNet(in_chans=64, n_classes=2, input_time_length=input_time_length,
                        final_conv_length=12).create_network()
to_dense_prediction_model(model)

if cuda:
    model.cuda()

# %%
from torch import optim

optimizer = optim.Adam(model.parameters())

# %%
from braindecode.torch_ext.util import np_to_var
# determine output size
test_input = np_to_var(np.ones((2, 64, input_time_length, 1), dtype=np.float32))
if cuda:
    test_input = test_input.cuda()
out = model(test_input)
n_preds_per_input = out.cpu().data.numpy().shape[2]
print("{:d} predictions per input/trial".format(n_preds_per_input))
# Out:
# 187 predictions per input/trial

# %%
from braindecode.datautil.iterators import CropsFromTrialsIterator
iterator = CropsFromTrialsIterator(batch_size=32,input_time_length=input_time_length,
                                  n_preds_per_input=n_preds_per_input)

# %%
from braindecode.experiments.experiment import Experiment

# %%
from braindecode.experiments.monitors import RuntimeMonitor, LossMonitor, CroppedTrialMisclassMonitor, MisclassMonitor
from braindecode.experiments.stopcriteria import MaxEpochs
import torch.nn.functional as F
import torch as th
from braindecode.torch_ext.modules import Expression


loss_function = lambda preds, targets: F.nll_loss(th.mean(preds, dim=2)[:,:,0], targets)

model_constraint = None
monitors = [LossMonitor(), MisclassMonitor(col_suffix='sample_misclass'),
            CroppedTrialMisclassMonitor(input_time_length), RuntimeMonitor(),]
stop_criterion = MaxEpochs(20)
exp = Experiment(model, train_set, valid_set, test_set, iterator, loss_function, optimizer, model_constraint,
          monitors, stop_criterion, remember_best_column='valid_misclass',
          run_after_early_stop=True, batch_modifier=None, cuda=cuda)

# %%
import logging
import sys
logging.basicConfig(format='%(asctime)s %(levelname)s : %(message)s',
                     level=logging.DEBUG, stream=sys.stdout)
exp.run()
# Out:
# 2017-07-04 12:38:00,093 INFO : Run until first stop...
# 2017-07-04 12:38:01,665 INFO : Epoch 0
# 2017-07-04 12:38:01,680 INFO : train_loss                0.98100
# 2017-07-04 12:38:01,683 INFO : valid_loss                0.75838
# 2017-07-04 12:38:01,685 INFO : test_loss                 0.76847
# 2017-07-04 12:38:01,687 INFO : train_sample_misclass     0.47839
# 2017-07-04 12:38:01,689 INFO : valid_sample_misclass     0.39416
# 2017-07-04 12:38:01,691 INFO : test_sample_misclass      0.39439
# 2017-07-04 12:38:01,692 INFO : train_misclass            0.50000
# 2017-07-04 12:38:01,694 INFO : valid_misclass            0.41667
# 2017-07-04 12:38:01,696 INFO : test_misclass             0.43333
# 2017-07-04 12:38:01,698 INFO : runtime                   0.00000
# 2017-07-04 12:38:01,700 INFO :
# 2017-07-04 12:38:01,703 INFO : New best valid_misclass: 0.416667
# 2017-07-04 12:38:01,706 INFO :
# 2017-07-04 12:38:06,164 INFO : Epoch 1
# 2017-07-04 12:38:06,177 INFO : train_loss                3.05195
# 2017-07-04 12:38:06,179 INFO : valid_loss                2.97197
# 2017-07-04 12:38:06,180 INFO : test_loss                 2.69628
# 2017-07-04 12:38:06,181 INFO : train_sample_misclass     0.48596
# 2017-07-04 12:38:06,182 INFO : valid_sample_misclass     0.50000
# 2017-07-04 12:38:06,184 INFO : test_sample_misclass      0.46667
# 2017-07-04 12:38:06,185 INFO : train_misclass            0.50000
# 2017-07-04 12:38:06,186 INFO : valid_misclass            0.50000
# 2017-07-04 12:38:06,187 INFO : test_misclass             0.46667
# 2017-07-04 12:38:06,189 INFO : runtime                   4.71008
# 2017-07-04 12:38:06,190 INFO :
# 2017-07-04 12:38:10,759 INFO : Epoch 2
# 2017-07-04 12:38:10,784 INFO : train_loss                0.77975
# 2017-07-04 12:38:10,789 INFO : valid_loss                0.92579
# 2017-07-04 12:38:10,790 INFO : test_loss                 0.81453
# 2017-07-04 12:38:10,791 INFO : train_sample_misclass     0.36648
# 2017-07-04 12:38:10,792 INFO : valid_sample_misclass     0.41087
# 2017-07-04 12:38:10,793 INFO : test_sample_misclass      0.42906
# 2017-07-04 12:38:10,794 INFO : train_misclass            0.29167
# 2017-07-04 12:38:10,795 INFO : valid_misclass            0.33333
# 2017-07-04 12:38:10,796 INFO : test_misclass             0.40000
# 2017-07-04 12:38:10,797 INFO : runtime                   4.24485
# 2017-07-04 12:38:10,798 INFO :
# 2017-07-04 12:38:10,800 INFO : New best valid_misclass: 0.333333
# 2017-07-04 12:38:10,813 INFO :
# 2017-07-04 12:38:17,448 INFO : Epoch 3
# 2017-07-04 12:38:17,465 INFO : train_loss                0.56242
# 2017-07-04 12:38:17,467 INFO : valid_loss                0.87425
# 2017-07-04 12:38:17,468 INFO : test_loss                 0.72686
# 2017-07-04 12:38:17,473 INFO : train_sample_misclass     0.29930
# 2017-07-04 12:38:17,474 INFO : valid_sample_misclass     0.48730
# 2017-07-04 12:38:17,475 INFO : test_sample_misclass      0.40455
# 2017-07-04 12:38:17,476 INFO : train_misclass            0.20833
# 2017-07-04 12:38:17,477 INFO : valid_misclass            0.33333
# 2017-07-04 12:38:17,479 INFO : test_misclass             0.33333
# 2017-07-04 12:38:17,480 INFO : runtime                   6.22607
# 2017-07-04 12:38:17,481 INFO :
# 2017-07-04 12:38:17,483 INFO : New best valid_misclass: 0.333333
# 2017-07-04 12:38:17,487 INFO :
# 2017-07-04 12:38:23,940 INFO : Epoch 4
# 2017-07-04 12:38:23,961 INFO : train_loss                0.47762
# 2017-07-04 12:38:23,963 INFO : valid_loss                0.95045
# 2017-07-04 12:38:23,965 INFO : test_loss                 0.72136
# 2017-07-04 12:38:23,966 INFO : train_sample_misclass     0.21697
# 2017-07-04 12:38:23,968 INFO : valid_sample_misclass     0.53676
# 2017-07-04 12:38:23,969 INFO : test_sample_misclass      0.39742
# 2017-07-04 12:38:23,970 INFO : train_misclass            0.14583
# 2017-07-04 12:38:23,972 INFO : valid_misclass            0.58333
# 2017-07-04 12:38:23,973 INFO : test_misclass             0.36667
# 2017-07-04 12:38:23,975 INFO : runtime                   6.26125
# 2017-07-04 12:38:23,976 INFO :
# 2017-07-04 12:38:29,900 INFO : Epoch 5
# 2017-07-04 12:38:29,915 INFO : train_loss                0.43118
# 2017-07-04 12:38:29,919 INFO : valid_loss                1.03074
# 2017-07-04 12:38:29,920 INFO : test_loss                 0.75704
# 2017-07-04 12:38:29,922 INFO : train_sample_misclass     0.19881
# 2017-07-04 12:38:29,924 INFO : valid_sample_misclass     0.52050
# 2017-07-04 12:38:29,926 INFO : test_sample_misclass      0.40918
# 2017-07-04 12:38:29,928 INFO : train_misclass            0.16667
# 2017-07-04 12:38:29,930 INFO : valid_misclass            0.50000
# 2017-07-04 12:38:29,932 INFO : test_misclass             0.40000
# 2017-07-04 12:38:29,934 INFO : runtime                   6.28946
# 2017-07-04 12:38:29,936 INFO :
# 2017-07-04 12:38:35,660 INFO : Epoch 6
# 2017-07-04 12:38:35,681 INFO : train_loss                0.40449
# 2017-07-04 12:38:35,682 INFO : valid_loss                1.06387
# 2017-07-04 12:38:35,682 INFO : test_loss                 0.79221
# 2017-07-04 12:38:35,683 INFO : train_sample_misclass     0.19001
# 2017-07-04 12:38:35,684 INFO : valid_sample_misclass     0.50267
# 2017-07-04 12:38:35,685 INFO : test_sample_misclass      0.40900
# 2017-07-04 12:38:35,685 INFO : train_misclass            0.16667
# 2017-07-04 12:38:35,686 INFO : valid_misclass            0.50000
# 2017-07-04 12:38:35,687 INFO : test_misclass             0.43333
# 2017-07-04 12:38:35,688 INFO : runtime                   6.02724
# 2017-07-04 12:38:35,688 INFO :
# 2017-07-04 12:38:42,945 INFO : Epoch 7
# 2017-07-04 12:38:42,947 INFO : train_loss                0.32355
# 2017-07-04 12:38:42,948 INFO : valid_loss                1.03384
# 2017-07-04 12:38:42,950 INFO : test_loss                 0.79468
# 2017-07-04 12:38:42,951 INFO : train_sample_misclass     0.14065
# 2017-07-04 12:38:42,953 INFO : valid_sample_misclass     0.51381
# 2017-07-04 12:38:42,954 INFO : test_sample_misclass      0.40071
# 2017-07-04 12:38:42,956 INFO : train_misclass            0.10417
# 2017-07-04 12:38:42,957 INFO : valid_misclass            0.50000
# 2017-07-04 12:38:42,959 INFO : test_misclass             0.36667
# 2017-07-04 12:38:42,960 INFO : runtime                   6.64543
# 2017-07-04 12:38:42,962 INFO :
# 2017-07-04 12:38:48,958 INFO : Epoch 8
# 2017-07-04 12:38:48,986 INFO : train_loss                0.26811
# 2017-07-04 12:38:48,987 INFO : valid_loss                0.99709
# 2017-07-04 12:38:48,988 INFO : test_loss                 0.77424
# 2017-07-04 12:38:48,989 INFO : train_sample_misclass     0.09770
# 2017-07-04 12:38:48,989 INFO : valid_sample_misclass     0.56907
# 2017-07-04 12:38:48,990 INFO : test_sample_misclass      0.38886
# 2017-07-04 12:38:48,991 INFO : train_misclass            0.04167
# 2017-07-04 12:38:48,991 INFO : valid_misclass            0.50000
# 2017-07-04 12:38:48,992 INFO : test_misclass             0.40000
# 2017-07-04 12:38:48,993 INFO : runtime                   6.64464
# 2017-07-04 12:38:48,993 INFO :
# 2017-07-04 12:38:54,930 INFO : Epoch 9
# 2017-07-04 12:38:54,932 INFO : train_loss                0.23189
# 2017-07-04 12:38:54,932 INFO : valid_loss                1.03192
# 2017-07-04 12:38:54,933 INFO : test_loss                 0.77594
# 2017-07-04 12:38:54,934 INFO : train_sample_misclass     0.07787
# 2017-07-04 12:38:54,935 INFO : valid_sample_misclass     0.56885
# 2017-07-04 12:38:54,935 INFO : test_sample_misclass      0.37781
# 2017-07-04 12:38:54,936 INFO : train_misclass            0.04167
# 2017-07-04 12:38:54,937 INFO : valid_misclass            0.41667
# 2017-07-04 12:38:54,937 INFO : test_misclass             0.36667
# 2017-07-04 12:38:54,938 INFO : runtime                   5.76952
# 2017-07-04 12:38:54,939 INFO :
# 2017-07-04 12:39:00,413 INFO : Epoch 10
# 2017-07-04 12:39:00,417 INFO : train_loss                0.20019
# 2017-07-04 12:39:00,419 INFO : valid_loss                1.10404
# 2017-07-04 12:39:00,421 INFO : test_loss                 0.81349
# 2017-07-04 12:39:00,423 INFO : train_sample_misclass     0.07503
# 2017-07-04 12:39:00,424 INFO : valid_sample_misclass     0.54501
# 2017-07-04 12:39:00,426 INFO : test_sample_misclass      0.35241
# 2017-07-04 12:39:00,426 INFO : train_misclass            0.06250
# 2017-07-04 12:39:00,427 INFO : valid_misclass            0.41667
# 2017-07-04 12:39:00,428 INFO : test_misclass             0.33333
# 2017-07-04 12:39:00,428 INFO : runtime                   5.58685
# 2017-07-04 12:39:00,429 INFO :
# 2017-07-04 12:39:04,797 INFO : Epoch 11
# 2017-07-04 12:39:04,799 INFO : train_loss                0.18081
# 2017-07-04 12:39:04,801 INFO : valid_loss                1.14962
# 2017-07-04 12:39:04,802 INFO : test_loss                 0.83604
# 2017-07-04 12:39:04,802 INFO : train_sample_misclass     0.06573
# 2017-07-04 12:39:04,803 INFO : valid_sample_misclass     0.52963
# 2017-07-04 12:39:04,804 INFO : test_sample_misclass      0.34367
# 2017-07-04 12:39:04,805 INFO : train_misclass            0.04167
# 2017-07-04 12:39:04,806 INFO : valid_misclass            0.41667
# 2017-07-04 12:39:04,807 INFO : test_misclass             0.30000
# 2017-07-04 12:39:04,808 INFO : runtime                   4.83624
# 2017-07-04 12:39:04,809 INFO :
# 2017-07-04 12:39:09,288 INFO : Epoch 12
# 2017-07-04 12:39:09,307 INFO : train_loss                0.14918
# 2017-07-04 12:39:09,308 INFO : valid_loss                1.15277
# 2017-07-04 12:39:09,308 INFO : test_loss                 0.88673
# 2017-07-04 12:39:09,309 INFO : train_sample_misclass     0.04729
# 2017-07-04 12:39:09,310 INFO : valid_sample_misclass     0.53253
# 2017-07-04 12:39:09,311 INFO : test_sample_misclass      0.32103
# 2017-07-04 12:39:09,311 INFO : train_misclass            0.02083
# 2017-07-04 12:39:09,312 INFO : valid_misclass            0.33333
# 2017-07-04 12:39:09,313 INFO : test_misclass             0.30000
# 2017-07-04 12:39:09,314 INFO : runtime                   4.82307
# 2017-07-04 12:39:09,314 INFO :
# 2017-07-04 12:39:09,316 INFO : New best valid_misclass: 0.333333
# 2017-07-04 12:39:09,317 INFO :
# 2017-07-04 12:39:13,071 INFO : Epoch 13
# 2017-07-04 12:39:13,074 INFO : train_loss                0.12957
# 2017-07-04 12:39:13,076 INFO : valid_loss                1.17418
# 2017-07-04 12:39:13,077 INFO : test_loss                 0.95112
# 2017-07-04 12:39:13,079 INFO : train_sample_misclass     0.03927
# 2017-07-04 12:39:13,080 INFO : valid_sample_misclass     0.49710
# 2017-07-04 12:39:13,082 INFO : test_sample_misclass      0.31390
# 2017-07-04 12:39:13,083 INFO : train_misclass            0.00000
# 2017-07-04 12:39:13,085 INFO : valid_misclass            0.41667
# 2017-07-04 12:39:13,086 INFO : test_misclass             0.23333
# 2017-07-04 12:39:13,088 INFO : runtime                   3.52326
# 2017-07-04 12:39:13,089 INFO :
# 2017-07-04 12:39:16,572 INFO : Epoch 14
# 2017-07-04 12:39:16,586 INFO : train_loss                0.13238
# 2017-07-04 12:39:16,589 INFO : valid_loss                1.21502
# 2017-07-04 12:39:16,591 INFO : test_loss                 1.00347
# 2017-07-04 12:39:16,592 INFO : train_sample_misclass     0.04629
# 2017-07-04 12:39:16,594 INFO : valid_sample_misclass     0.44340
# 2017-07-04 12:39:16,596 INFO : test_sample_misclass      0.31480
# 2017-07-04 12:39:16,598 INFO : train_misclass            0.00000
# 2017-07-04 12:39:16,600 INFO : valid_misclass            0.50000
# 2017-07-04 12:39:16,602 INFO : test_misclass             0.26667
# 2017-07-04 12:39:16,604 INFO : runtime                   3.83794
# 2017-07-04 12:39:16,606 INFO :
# 2017-07-04 12:39:20,052 INFO : Epoch 15
# 2017-07-04 12:39:20,061 INFO : train_loss                0.10248
# 2017-07-04 12:39:20,064 INFO : valid_loss                1.23828
# 2017-07-04 12:39:20,066 INFO : test_loss                 0.98638
# 2017-07-04 12:39:20,069 INFO : train_sample_misclass     0.03359
# 2017-07-04 12:39:20,071 INFO : valid_sample_misclass     0.43182
# 2017-07-04 12:39:20,072 INFO : test_sample_misclass      0.30000
# 2017-07-04 12:39:20,074 INFO : train_misclass            0.02083
# 2017-07-04 12:39:20,076 INFO : valid_misclass            0.33333
# 2017-07-04 12:39:20,078 INFO : test_misclass             0.33333
# 2017-07-04 12:39:20,080 INFO : runtime                   3.48901
# 2017-07-04 12:39:20,081 INFO :
# 2017-07-04 12:39:20,084 INFO : New best valid_misclass: 0.333333
# 2017-07-04 12:39:20,088 INFO :
# 2017-07-04 12:39:23,442 INFO : Epoch 16
# 2017-07-04 12:39:23,445 INFO : train_loss                0.07767
# 2017-07-04 12:39:23,446 INFO : valid_loss                1.20868
# 2017-07-04 12:39:23,448 INFO : test_loss                 1.03494
# 2017-07-04 12:39:23,449 INFO : train_sample_misclass     0.02501
# 2017-07-04 12:39:23,450 INFO : valid_sample_misclass     0.38414
# 2017-07-04 12:39:23,452 INFO : test_sample_misclass      0.29973
# 2017-07-04 12:39:23,453 INFO : train_misclass            0.00000
# 2017-07-04 12:39:23,455 INFO : valid_misclass            0.33333
# 2017-07-04 12:39:23,456 INFO : test_misclass             0.26667
# 2017-07-04 12:39:23,458 INFO : runtime                   3.69017
# 2017-07-04 12:39:23,459 INFO :
# 2017-07-04 12:39:23,462 INFO : New best valid_misclass: 0.333333
# 2017-07-04 12:39:23,463 INFO :
# 2017-07-04 12:39:26,623 INFO : Epoch 17
# 2017-07-04 12:39:26,637 INFO : train_loss                0.08780
# 2017-07-04 12:39:26,640 INFO : valid_loss                1.18799
# 2017-07-04 12:39:26,642 INFO : test_loss                 1.06005
# 2017-07-04 12:39:26,644 INFO : train_sample_misclass     0.02913
# 2017-07-04 12:39:26,646 INFO : valid_sample_misclass     0.38235
# 2017-07-04 12:39:26,648 INFO : test_sample_misclass      0.31480
# 2017-07-04 12:39:26,650 INFO : train_misclass            0.00000
# 2017-07-04 12:39:26,653 INFO : valid_misclass            0.41667
# 2017-07-04 12:39:26,655 INFO : test_misclass             0.26667
# 2017-07-04 12:39:26,656 INFO : runtime                   2.93644
# 2017-07-04 12:39:26,658 INFO :
# 2017-07-04 12:39:29,159 INFO : Epoch 18
# 2017-07-04 12:39:29,160 INFO : train_loss                0.07780
# 2017-07-04 12:39:29,161 INFO : valid_loss                1.22047
# 2017-07-04 12:39:29,162 INFO : test_loss                 1.03780
# 2017-07-04 12:39:29,164 INFO : train_sample_misclass     0.02730
# 2017-07-04 12:39:29,165 INFO : valid_sample_misclass     0.37901
# 2017-07-04 12:39:29,167 INFO : test_sample_misclass      0.30588
# 2017-07-04 12:39:29,168 INFO : train_misclass            0.00000
# 2017-07-04 12:39:29,170 INFO : valid_misclass            0.50000
# 2017-07-04 12:39:29,171 INFO : test_misclass             0.26667
# 2017-07-04 12:39:29,173 INFO : runtime                   2.98111
# 2017-07-04 12:39:29,174 INFO :
# 2017-07-04 12:39:30,920 INFO : Epoch 19
# 2017-07-04 12:39:30,922 INFO : train_loss                0.04222
# 2017-07-04 12:39:30,922 INFO : valid_loss                1.32549
# 2017-07-04 12:39:30,923 INFO : test_loss                 1.07507
# 2017-07-04 12:39:30,924 INFO : train_sample_misclass     0.00674
# 2017-07-04 12:39:30,925 INFO : valid_sample_misclass     0.41889
# 2017-07-04 12:39:30,926 INFO : test_sample_misclass      0.29483
# 2017-07-04 12:39:30,926 INFO : train_misclass            0.00000
# 2017-07-04 12:39:30,927 INFO : valid_misclass            0.41667
# 2017-07-04 12:39:30,928 INFO : test_misclass             0.26667
# 2017-07-04 12:39:30,929 INFO : runtime                   1.68740
# 2017-07-04 12:39:30,929 INFO :
# 2017-07-04 12:39:32,790 INFO : Epoch 20
# 2017-07-04 12:39:32,792 INFO : train_loss                0.03722
# 2017-07-04 12:39:32,797 INFO : valid_loss                1.39442
# 2017-07-04 12:39:32,803 INFO : test_loss                 1.22179
# 2017-07-04 12:39:32,804 INFO : train_sample_misclass     0.00841
# 2017-07-04 12:39:32,806 INFO : valid_sample_misclass     0.40419
# 2017-07-04 12:39:32,807 INFO : test_sample_misclass      0.30009
# 2017-07-04 12:39:32,809 INFO : train_misclass            0.00000
# 2017-07-04 12:39:32,810 INFO : valid_misclass            0.33333
# 2017-07-04 12:39:32,812 INFO : test_misclass             0.30000
# 2017-07-04 12:39:32,813 INFO : runtime                   1.90066
# 2017-07-04 12:39:32,814 INFO :
# 2017-07-04 12:39:32,816 INFO : New best valid_misclass: 0.333333
# 2017-07-04 12:39:32,818 INFO :
# 2017-07-04 12:39:32,819 INFO : Setup for second stop...
# 2017-07-04 12:39:32,822 INFO : Train loss to reach 0.03722
# 2017-07-04 12:39:32,825 INFO : Run until second stop...
# 2017-07-04 12:39:33,324 INFO : Epoch 21
# 2017-07-04 12:39:33,327 INFO : train_loss                0.30866
# 2017-07-04 12:39:33,328 INFO : valid_loss                1.39442
# 2017-07-04 12:39:33,330 INFO : test_loss                 1.22179
# 2017-07-04 12:39:33,331 INFO : train_sample_misclass     0.08757
# 2017-07-04 12:39:33,333 INFO : valid_sample_misclass     0.40419
# 2017-07-04 12:39:33,334 INFO : test_sample_misclass      0.30009
# 2017-07-04 12:39:33,336 INFO : train_misclass            0.06667
# 2017-07-04 12:39:33,337 INFO : valid_misclass            0.33333
# 2017-07-04 12:39:33,339 INFO : test_misclass             0.30000
# 2017-07-04 12:39:33,340 INFO : runtime                   0.62311
# 2017-07-04 12:39:33,342 INFO :
# 2017-07-04 12:39:35,537 INFO : Epoch 22
# 2017-07-04 12:39:35,540 INFO : train_loss                0.21399
# 2017-07-04 12:39:35,541 INFO : valid_loss                0.66868
# 2017-07-04 12:39:35,543 INFO : test_loss                 1.02008
# 2017-07-04 12:39:35,544 INFO : train_sample_misclass     0.07611
# 2017-07-04 12:39:35,546 INFO : valid_sample_misclass     0.23819
# 2017-07-04 12:39:35,547 INFO : test_sample_misclass      0.26266
# 2017-07-04 12:39:35,549 INFO : train_misclass            0.08333
# 2017-07-04 12:39:35,550 INFO : valid_misclass            0.33333
# 2017-07-04 12:39:35,552 INFO : test_misclass             0.26667
# 2017-07-04 12:39:35,554 INFO : runtime                   2.10195
# 2017-07-04 12:39:35,555 INFO :
# 2017-07-04 12:39:37,667 INFO : Epoch 23
# 2017-07-04 12:39:37,670 INFO : train_loss                0.24799
# 2017-07-04 12:39:37,671 INFO : valid_loss                0.90140
# 2017-07-04 12:39:37,673 INFO : test_loss                 1.12544
# 2017-07-04 12:39:37,674 INFO : train_sample_misclass     0.07625
# 2017-07-04 12:39:37,676 INFO : valid_sample_misclass     0.25735
# 2017-07-04 12:39:37,677 INFO : test_sample_misclass      0.28351
# 2017-07-04 12:39:37,679 INFO : train_misclass            0.05000
# 2017-07-04 12:39:37,680 INFO : valid_misclass            0.16667
# 2017-07-04 12:39:37,682 INFO : test_misclass             0.23333
# 2017-07-04 12:39:37,683 INFO : runtime                   2.11847
# 2017-07-04 12:39:37,685 INFO :
# 2017-07-04 12:39:40,092 INFO : Epoch 24
# 2017-07-04 12:39:40,095 INFO : train_loss                0.15427
# 2017-07-04 12:39:40,096 INFO : valid_loss                0.55240
# 2017-07-04 12:39:40,098 INFO : test_loss                 0.87812
# 2017-07-04 12:39:40,099 INFO : train_sample_misclass     0.05740
# 2017-07-04 12:39:40,100 INFO : valid_sample_misclass     0.21970
# 2017-07-04 12:39:40,102 INFO : test_sample_misclass      0.25561
# 2017-07-04 12:39:40,103 INFO : train_misclass            0.01667
# 2017-07-04 12:39:40,105 INFO : valid_misclass            0.08333
# 2017-07-04 12:39:40,106 INFO : test_misclass             0.23333
# 2017-07-04 12:39:40,108 INFO : runtime                   2.40494
# 2017-07-04 12:39:40,109 INFO :
# 2017-07-04 12:39:42,249 INFO : Epoch 25
# 2017-07-04 12:39:42,250 INFO : train_loss                0.10207
# 2017-07-04 12:39:42,252 INFO : valid_loss                0.28607
# 2017-07-04 12:39:42,253 INFO : test_loss                 0.83391
# 2017-07-04 12:39:42,255 INFO : train_sample_misclass     0.03761
# 2017-07-04 12:39:42,256 INFO : valid_sample_misclass     0.11430
# 2017-07-04 12:39:42,258 INFO : test_sample_misclass      0.24109
# 2017-07-04 12:39:42,259 INFO : train_misclass            0.01667
# 2017-07-04 12:39:42,261 INFO : valid_misclass            0.08333
# 2017-07-04 12:39:42,262 INFO : test_misclass             0.23333
# 2017-07-04 12:39:42,264 INFO : runtime                   2.17289
# 2017-07-04 12:39:42,265 INFO :
# 2017-07-04 12:39:44,359 INFO : Epoch 26
# 2017-07-04 12:39:44,362 INFO : train_loss                0.08549
# 2017-07-04 12:39:44,363 INFO : valid_loss                0.27644
# 2017-07-04 12:39:44,365 INFO : test_loss                 0.87043
# 2017-07-04 12:39:44,366 INFO : train_sample_misclass     0.03142
# 2017-07-04 12:39:44,368 INFO : valid_sample_misclass     0.11698
# 2017-07-04 12:39:44,369 INFO : test_sample_misclass      0.24697
# 2017-07-04 12:39:44,371 INFO : train_misclass            0.03333
# 2017-07-04 12:39:44,372 INFO : valid_misclass            0.16667
# 2017-07-04 12:39:44,374 INFO : test_misclass             0.23333
# 2017-07-04 12:39:44,375 INFO : runtime                   2.17360
# 2017-07-04 12:39:44,377 INFO :
# 2017-07-04 12:39:46,306 INFO : Epoch 27
# 2017-07-04 12:39:46,307 INFO : train_loss                0.26862
# 2017-07-04 12:39:46,309 INFO : valid_loss                0.35562
# 2017-07-04 12:39:46,310 INFO : test_loss                 0.93244
# 2017-07-04 12:39:46,312 INFO : train_sample_misclass     0.06493
# 2017-07-04 12:39:46,313 INFO : valid_sample_misclass     0.12366
# 2017-07-04 12:39:46,315 INFO : test_sample_misclass      0.26488
# 2017-07-04 12:39:46,316 INFO : train_misclass            0.06667
# 2017-07-04 12:39:46,318 INFO : valid_misclass            0.16667
# 2017-07-04 12:39:46,319 INFO : test_misclass             0.23333
# 2017-07-04 12:39:46,321 INFO : runtime                   1.95969
# 2017-07-04 12:39:46,322 INFO :
# 2017-07-04 12:39:48,384 INFO : Epoch 28
# 2017-07-04 12:39:48,386 INFO : train_loss                0.19586
# 2017-07-04 12:39:48,388 INFO : valid_loss                0.31243
# 2017-07-04 12:39:48,389 INFO : test_loss                 0.85692
# 2017-07-04 12:39:48,391 INFO : train_sample_misclass     0.08614
# 2017-07-04 12:39:48,392 INFO : valid_sample_misclass     0.13837
# 2017-07-04 12:39:48,394 INFO : test_sample_misclass      0.25615
# 2017-07-04 12:39:48,395 INFO : train_misclass            0.06667
# 2017-07-04 12:39:48,397 INFO : valid_misclass            0.00000
# 2017-07-04 12:39:48,398 INFO : test_misclass             0.26667
# 2017-07-04 12:39:48,400 INFO : runtime                   2.01687
# 2017-07-04 12:39:48,401 INFO :
# 2017-07-04 12:39:50,551 INFO : Epoch 29
# 2017-07-04 12:39:50,553 INFO : train_loss                0.09439
# 2017-07-04 12:39:50,555 INFO : valid_loss                0.25974
# 2017-07-04 12:39:50,556 INFO : test_loss                 0.72014
# 2017-07-04 12:39:50,558 INFO : train_sample_misclass     0.03124
# 2017-07-04 12:39:50,559 INFO : valid_sample_misclass     0.09603
# 2017-07-04 12:39:50,561 INFO : test_sample_misclass      0.22897
# 2017-07-04 12:39:50,562 INFO : train_misclass            0.01667
# 2017-07-04 12:39:50,564 INFO : valid_misclass            0.08333
# 2017-07-04 12:39:50,565 INFO : test_misclass             0.20000
# 2017-07-04 12:39:50,567 INFO : runtime                   2.08059
# 2017-07-04 12:39:50,568 INFO :
# 2017-07-04 12:39:52,569 INFO : Epoch 30
# 2017-07-04 12:39:52,570 INFO : train_loss                0.07061
# 2017-07-04 12:39:52,571 INFO : valid_loss                0.20127
# 2017-07-04 12:39:52,572 INFO : test_loss                 0.77256
# 2017-07-04 12:39:52,574 INFO : train_sample_misclass     0.02068
# 2017-07-04 12:39:52,575 INFO : valid_sample_misclass     0.07776
# 2017-07-04 12:39:52,577 INFO : test_sample_misclass      0.21667
# 2017-07-04 12:39:52,578 INFO : train_misclass            0.01667
# 2017-07-04 12:39:52,580 INFO : valid_misclass            0.08333
# 2017-07-04 12:39:52,581 INFO : test_misclass             0.20000
# 2017-07-04 12:39:52,583 INFO : runtime                   2.08599
# 2017-07-04 12:39:52,584 INFO :
# 2017-07-04 12:39:54,600 INFO : Epoch 31
# 2017-07-04 12:39:54,602 INFO : train_loss                0.05399
# 2017-07-04 12:39:54,604 INFO : valid_loss                0.14631
# 2017-07-04 12:39:54,605 INFO : test_loss                 0.78314
# 2017-07-04 12:39:54,607 INFO : train_sample_misclass     0.01916
# 2017-07-04 12:39:54,608 INFO : valid_sample_misclass     0.06573
# 2017-07-04 12:39:54,610 INFO : test_sample_misclass      0.18298
# 2017-07-04 12:39:54,611 INFO : train_misclass            0.00000
# 2017-07-04 12:39:54,613 INFO : valid_misclass            0.00000
# 2017-07-04 12:39:54,614 INFO : test_misclass             0.20000
# 2017-07-04 12:39:54,616 INFO : runtime                   2.00103
# 2017-07-04 12:39:54,617 INFO :
# 2017-07-04 12:39:56,776 INFO : Epoch 32
# 2017-07-04 12:39:56,778 INFO : train_loss                0.04836
# 2017-07-04 12:39:56,780 INFO : valid_loss                0.10775
# 2017-07-04 12:39:56,781 INFO : test_loss                 0.75863
# 2017-07-04 12:39:56,783 INFO : train_sample_misclass     0.01582
# 2017-07-04 12:39:56,784 INFO : valid_sample_misclass     0.04724
# 2017-07-04 12:39:56,786 INFO : test_sample_misclass      0.18280
# 2017-07-04 12:39:56,787 INFO : train_misclass            0.00000
# 2017-07-04 12:39:56,789 INFO : valid_misclass            0.00000
# 2017-07-04 12:39:56,790 INFO : test_misclass             0.20000
# 2017-07-04 12:39:56,792 INFO : runtime                   2.19598
# 2017-07-04 12:39:56,793 INFO :
# 2017-07-04 12:39:58,961 INFO : Epoch 33
# 2017-07-04 12:39:58,964 INFO : train_loss                0.03574
# 2017-07-04 12:39:58,965 INFO : valid_loss                0.09682
# 2017-07-04 12:39:58,967 INFO : test_loss                 0.79201
# 2017-07-04 12:39:58,968 INFO : train_sample_misclass     0.01110
# 2017-07-04 12:39:58,969 INFO : valid_sample_misclass     0.04011
# 2017-07-04 12:39:58,971 INFO : test_sample_misclass      0.17923
# 2017-07-04 12:39:58,972 INFO : train_misclass            0.00000
# 2017-07-04 12:39:58,974 INFO : valid_misclass            0.00000
# 2017-07-04 12:39:58,975 INFO : test_misclass             0.16667
# 2017-07-04 12:39:58,977 INFO : runtime                   2.25382
# 2017-07-04 12:39:58,978 INFO :
# 2017-07-04 12:40:01,167 INFO : Epoch 34
# 2017-07-04 12:40:01,169 INFO : train_loss                0.02600
# 2017-07-04 12:40:01,170 INFO : valid_loss                0.06539
# 2017-07-04 12:40:01,172 INFO : test_loss                 0.82955
# 2017-07-04 12:40:01,173 INFO : train_sample_misclass     0.00673
# 2017-07-04 12:40:01,175 INFO : valid_sample_misclass     0.02295
# 2017-07-04 12:40:01,176 INFO : test_sample_misclass      0.18663
# 2017-07-04 12:40:01,178 INFO : train_misclass            0.00000
# 2017-07-04 12:40:01,179 INFO : valid_misclass            0.00000
# 2017-07-04 12:40:01,181 INFO : test_misclass             0.20000
# 2017-07-04 12:40:01,182 INFO : runtime                   2.19335
# 2017-07-04 12:40:01,184 INFO :
# 2017-07-04 12:40:03,589 INFO : Epoch 35
# 2017-07-04 12:40:03,592 INFO : train_loss                0.01859
# 2017-07-04 12:40:03,593 INFO : valid_loss                0.04725
# 2017-07-04 12:40:03,595 INFO : test_loss                 0.82204
# 2017-07-04 12:40:03,596 INFO : train_sample_misclass     0.00463
# 2017-07-04 12:40:03,598 INFO : valid_sample_misclass     0.01627
# 2017-07-04 12:40:03,599 INFO : test_sample_misclass      0.18788
# 2017-07-04 12:40:03,601 INFO : train_misclass            0.00000
# 2017-07-04 12:40:03,602 INFO : valid_misclass            0.00000
# 2017-07-04 12:40:03,604 INFO : test_misclass             0.16667
# 2017-07-04 12:40:03,605 INFO : runtime                   2.48033
# 2017-07-04 12:40:03,607 INFO :
# 2017-07-04 12:40:05,543 INFO : Epoch 36
# 2017-07-04 12:40:05,545 INFO : train_loss                0.01583
# 2017-07-04 12:40:05,546 INFO : valid_loss                0.04626
# 2017-07-04 12:40:05,548 INFO : test_loss                 0.86053
# 2017-07-04 12:40:05,549 INFO : train_sample_misclass     0.00414
# 2017-07-04 12:40:05,551 INFO : valid_sample_misclass     0.01693
# 2017-07-04 12:40:05,552 INFO : test_sample_misclass      0.19046
# 2017-07-04 12:40:05,554 INFO : train_misclass            0.00000
# 2017-07-04 12:40:05,555 INFO : valid_misclass            0.00000
# 2017-07-04 12:40:05,557 INFO : test_misclass             0.20000
# 2017-07-04 12:40:05,558 INFO : runtime                   1.99063
# 2017-07-04 12:40:05,560 INFO :
# 2017-07-04 12:40:07,349 INFO : Epoch 37
# 2017-07-04 12:40:07,352 INFO : train_loss                0.01295
# 2017-07-04 12:40:07,353 INFO : valid_loss                0.03537
# 2017-07-04 12:40:07,355 INFO : test_loss                 0.87311
# 2017-07-04 12:40:07,356 INFO : train_sample_misclass     0.00299
# 2017-07-04 12:40:07,358 INFO : valid_sample_misclass     0.01292
# 2017-07-04 12:40:07,359 INFO : test_sample_misclass      0.17986
# 2017-07-04 12:40:07,361 INFO : train_misclass            0.00000
# 2017-07-04 12:40:07,362 INFO : valid_misclass            0.00000
# 2017-07-04 12:40:07,364 INFO : test_misclass             0.16667
# 2017-07-04 12:40:07,365 INFO : runtime                   1.82635
# 2017-07-04 12:40:07,367 INFO :

# %% [markdown]
# In this case, we arrive at 83.3% accuracy, the training stops after the validation loss decreases below the training loss at the best epoch of 0.03722.

# %% [markdown]
# ## Dataset References

# %% [markdown]
#  This dataset was created and contributed to PhysioNet by the developers of the [BCI2000](http://www.schalklab.org/research/bci2000) instrumentation system, which they used in making these recordings. The system is described in:
#
#      Schalk, G., McFarland, D.J., Hinterberger, T., Birbaumer, N., Wolpaw, J.R. (2004) BCI2000: A General-Purpose Brain-Computer Interface (BCI) System. IEEE TBME 51(6):1034-1043.
#
# [PhysioBank](https://physionet.org/physiobank/) is a large and growing archive of well-characterized digital recordings of physiologic signals and related data for use by the biomedical research community and further described in:
#
#     Goldberger AL, Amaral LAN, Glass L, Hausdorff JM, Ivanov PCh, Mark RG, Mietus JE, Moody GB, Peng C-K, Stanley HE. (2000) PhysioBank, PhysioToolkit, and PhysioNet: Components of a New Research Resource for Complex Physiologic Signals. Circulation 101(23):e215-e220.
